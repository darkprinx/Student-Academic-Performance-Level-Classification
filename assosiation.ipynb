# %%
import pandas as pd
import numpy as np
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import association_rules,apriori

# %%
kd = pd.read_csv('edu.csv', delimiter=',')
kd = kd.drop(list(kd)[4:-2],axis=1)
kd = kd.drop(list(kd)[0],axis=1)
kd = np.array(kd)

te = TransactionEncoder()
te_ary = te.fit(kd).transform(kd)
df = pd.DataFrame(te_ary,columns=te.columns_)
fi = apriori(df,min_support=0.1,use_colnames=True)

# this part is for apriory all for the item combination above 2 itemsets and minimum support 0.1
fi[fi['itemsets'].apply(lambda x:len(x))>2]
# Out:
#       support                            itemsets
# 55   0.183333                (Above-7, A, Father)
# 56   0.139583                     (Above-7, L, A)
# 57   0.133333          (Above-7, A, MiddleSchool)
# 58   0.125000                      (L, A, Father)
# 59   0.172917                      (A, M, Father)
# 60   0.214583           (A, MiddleSchool, Father)
# 61   0.168750                (Father, A, Under-7)
# 62   0.104167             (A, lowerlevel, Father)
# 63   0.120833                (H, A, MiddleSchool)
# 64   0.120833                         (H, A, Mum)
# 65   0.172917                     (H, A, Under-7)
# 66   0.179167                (A, M, MiddleSchool)
# 67   0.168750                     (A, M, Under-7)
# 68   0.162500              (A, Mum, MiddleSchool)
# 69   0.243750          (A, MiddleSchool, Under-7)
# 70   0.181250                   (A, Mum, Under-7)
# 71   0.193750                (Above-7, L, Father)
# 72   0.129167     (Above-7, MiddleSchool, Father)
# 73   0.139583       (Above-7, lowerlevel, Father)
# 74   0.100000          (Above-7, L, MiddleSchool)
# 75   0.125000            (Above-7, L, lowerlevel)
# 76   0.104167                (Father, B, Under-7)
# 77   0.114583             (B, lowerlevel, Father)
# 78   0.104167                     (H, B, Under-7)
# 79   0.104167                   (B, Mum, Under-7)
# 80   0.110417                (B, Mum, lowerlevel)
# 81   0.131250            (B, lowerlevel, Under-7)
# 82   0.106250             (L, lowerlevel, Father)
# 83   0.162500           (M, MiddleSchool, Father)
# 84   0.193750                (Father, M, Under-7)
# 85   0.175000     (Father, MiddleSchool, Under-7)
# 86   0.100000       (Father, lowerlevel, Under-7)
# 87   0.112500              (H, Mum, MiddleSchool)
# 88   0.154167          (H, MiddleSchool, Under-7)
# 89   0.202083                   (H, Mum, Under-7)
# 90   0.112500            (H, lowerlevel, Under-7)
# 91   0.168750          (M, MiddleSchool, Under-7)
# 92   0.160417        (Mum, MiddleSchool, Under-7)
# 93   0.120833          (Mum, lowerlevel, Under-7)
# 94   0.116667             (Above-7, L, A, Father)
# 95   0.110417        (A, M, MiddleSchool, Father)
# 96   0.106250             (Father, A, M, Under-7)
# 97   0.116667  (Father, A, MiddleSchool, Under-7)
# 98   0.118750       (H, A, MiddleSchool, Under-7)
# 99   0.118750                (H, A, Mum, Under-7)
# 100  0.116667       (A, M, MiddleSchool, Under-7)
# 101  0.127083     (A, Mum, MiddleSchool, Under-7)
# 102  0.116667  (Father, M, MiddleSchool, Under-7)
# 103  0.108333     (H, Mum, MiddleSchool, Under-7)

# %%
# correlation part for showing confidence and lift

rules = association_rules(fi, metric="lift", min_threshold=2)
xx = rules['antecedents'].apply(lambda x:len(x))
final_rules = rules[xx>2].sort_values('confidence',ascending = False)
final_rules
# Out:
#                      antecedents consequents  antecedent support  \
# 1                 (L, A, Father)   (Above-7)            0.125000
# 22  (Mum, MiddleSchool, Under-7)         (H)            0.160417
# 18             (A, Mum, Under-7)         (H)            0.181250
# 0           (Above-7, A, Father)         (L)            0.183333
#
#     consequent support   support  confidence      lift  leverage  conviction
# 1             0.397917  0.116667    0.933333  2.345550  0.066927    9.031250
# 22            0.295833  0.108333    0.675325  2.282788  0.060877    2.168833
# 18            0.295833  0.118750    0.655172  2.214667  0.065130    2.042083
# 0             0.264583  0.116667    0.636364  2.405154  0.068160    2.022396
